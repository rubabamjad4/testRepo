# %% [markdown]
# <a href="https://colab.research.google.com/github/rubabamjad4/testRepo/blob/main/w03_data_contract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %% [markdown]
# ## Unit of Analysis
#
# One row represents one search record for a webpage (or query, depending on the dataset) on a single day.
#
# ## Time Window
#
# This notebook uses data from March 2026 (month = '2026-03').
#
# A mid-panel month is chosen to avoid using the final month (June 2026), which should remain an unseen test period.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %% [markdown]
# ### Features
#
# - clicks
# - impressions
# - ctr
# - average_position
# - device
#
# ### Label
#
# - Future clicks (prediction target)
#
# ### Context
#
# - date
# - page
# - country
#
# ### Excluded
#
# - June 2026 data (reserved as test period)
# - Future performance metrics (would leak information)

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
con.execute("""
SELECT
    page,
    date,
    COUNT(*) AS duplicate_rows
FROM search_console_daily
WHERE month='2026-03'
GROUP BY page, date
HAVING COUNT(*) > 1;
""").df()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2090/4036276018.py in <cell line: 0>()
# ----> 1 con.execute("""
#       2 SELECT
#       3     page,
#       4     date,
#       5     COUNT(*) AS duplicate_rows
#
# NameError: name 'con' is not defined

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %% [markdown]
# ## Data Limits
#
# This dataset only contains Search Console information.
#
# It does not explain why user behavior changes.
#
# Seasonality outside the selected month is not represented.
#
# The final month (June 2026) is excluded to avoid leakage into future predictions.
#
# These results should be used for decision support rather than causal conclusions.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
